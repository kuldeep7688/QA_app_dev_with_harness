# %% [markdown]
# # Gemma-2-2B-IT Poem Generator
#
# This notebook uses NVIDIA's Build with AI API (OpenAI-compatible) to generate poems using the Gemma-2-2B-IT model.

# %%
# !pip install python-dotenv openai -q
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
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

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

NVIDIA_API_KEY = os.getenv("NVIDIA_API_KEY")
print(f"API Key loaded: {'Yes' if NVIDIA_API_KEY else 'No'}")

# Initialize OpenAI client with NVIDIA's base URL
client = OpenAI(
    base_url="https://integrate.api.nvidia.com/v1",
    api_key=NVIDIA_API_KEY
)
# Out:
# API Key loaded: Yes

# %%
def generate_poem(prompt: str, max_tokens: int = 200, temperature: float = 0.8) -> str:
    """
    Generate a poem using Gemma-2-2B-IT via NVIDIA's API (OpenAI-compatible).
    
    Args:
        prompt: The prompt to generate a poem from
        max_tokens: Maximum tokens to generate
        temperature: Sampling temperature (0.0-1.0)
    
    Returns:
        Generated poem text
    """
    completion = client.chat.completions.create(
        model="google/gemma-2-2b-it",
        messages=[
            {
                "role": "assistant",
                "content": "You are a creative poet. Write beautiful, evocative poems."
            },
            {
                "role": "user",
                "content": prompt
            }
        ],
        max_tokens=max_tokens,
        temperature=temperature,
        top_p=0.9,
        stream=False
    )
    
    return completion

# %%
# Generate a poem about nature
prompt = "Write a poem about a peaceful forest at dawn"
poem = generate_poem(prompt)
print(poem)
# Out:
# ChatCompletion(id='4e6ebf5f-9d9f-4bcc-983f-24bada252870', choices=[Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content="The sun, a shy, newborn eye, peeks through the boughs,\nA blush of gold upon the dew-kissed grass.\nThe forest sighs, a hushed and ancient vow,\nAs shadows dance and linger in the glass.\n\nA gentle breeze, a whisper through the trees,\nUnveils a tapestry of emerald green.\nWhere moss-draped oaks stand sentinel, at ease,\nAnd sunlight spills a liquid, golden sheen.\n\nA spider's web, a glistening, silver thread,\nHangs in the morning's cool embrace so deep.\nA robin sings a sweet and hopeful tread,\nA melody that lulls the world to sleep.\n\nThe air is crisp, with scent of pine and wood,\nA symphony of quiet, life reborn.\nThe forest sleeps, yet magic fills the hood,\nA whispered promise on the dawning morn.\n\nAnd as the light climbs higher, bright and bold,\nThe world awakens,", refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=None, model=None, object=None, moderation=None, service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=200, prompt_tokens=32, total_tokens=232, completion_tokens_details=None, prompt_tokens_details=None))

# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "$NVIDIA_API_KEY"
)

completion = client.chat.completions.create(
  model="google/gemma-2-2b-it",
  messages=[{"role":"user","content":""}],
  temperature=0.2,
  top_p=0.7,
  max_tokens=1024,
  stream=False
)

print(completion.choices[0].message)

# %%
import OpenAI from 'openai';

const openai = new OpenAI({
  apiKey: '$NVIDIA_API_KEY',
  baseURL: 'https://integrate.api.nvidia.com/v1',
})

async function main() {
  const completion = await openai.chat.completions.create({
    model: "google/gemma-2-2b-it",
    messages: [{"role":"user","content":""}],
    temperature: 0.2,
    top_p: 0.7,
    max_tokens: 1024,
    stream: false,
  })
   
  process.stdout.write(completion.choices[0]?.message?.content);
  
}

main();
